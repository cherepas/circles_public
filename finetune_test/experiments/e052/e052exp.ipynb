# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.scatter(np.array([1,2,3,4,6,8,12]),[570,447,468,504,449,380,329], label = 'Densenet')
plt.scatter([2, 3, 6, 8], [441, 433, 447, 361], label = '8-Layers net')
plt.xlabel('Number of GPUs')
plt.ylabel('Elapsed time for 2 epochs, s')
plt.axis([0.5, 12.5, 0, 600])
#plt.title('Densenet')
plt.legend(
    bbox_to_anchor=(1.05, 1),
    loc='best', borderaxespad=0., fontsize=18)

# %%
plt.xlabel('Number of GPUs')
plt.ylabel('Elapsed time for 2 epochs, s')
plt.axis([1.5, 8.5, 0, 460])
plt.title('8-layers network')
# Out:
# Text(0.5, 1.0, '8-layers network')
